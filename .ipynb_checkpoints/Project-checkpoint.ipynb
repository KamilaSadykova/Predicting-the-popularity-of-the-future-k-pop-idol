# %%
#import libraries
import pandas as pd

# %%
#read dataset
data = pd.read_csv("kpopdataset.csv",sep="\t",delimiter = ";")
data.head()
# Out:
#    rank   name            agency   real name      group   age  height  weight  \
# 0     1  Jinah  주식회사 씨그널엔터테인먼트그룹  Seo Jin Ah  Berry Chu  37.0     NaN     NaN
# 1     2  Hayul  주식회사 씨그널엔터테인먼트그룹  Kim Ha Yul  Berry Chu  33.0     NaN     NaN
# 2     3  Jieun  주식회사 씨그널엔터테인먼트그룹  Han Ji Eun  Berry Chu  33.0     NaN     NaN
# 3     4  Yunmi  주식회사 씨그널엔터테인먼트그룹  Heo Yun Mi  Berry Chu  32.0     NaN     NaN
# 4     5   Haum  주식회사 씨그널엔터테인먼트그룹    Kim Haum  Berry Chu  29.0     NaN     NaN
#
#   blood type   origin      country          position industry  gender  \
# 0        NaN    Seoul  South Korea  Leader, Vocalist    K-pop  Female
# 1        NaN    Seoul  South Korea          Vocalist    K-pop  Female
# 2        NaN    Seoul  South Korea          Vocalist    K-pop  Female
# 3        NaN  Incheon  South Korea          Vocalist    K-pop  Female
# 4        NaN    Seoul  South Korea  Vocalist, Maknae    K-pop  Female
#
#     curr date  birth date
# 0  23.04.2020  29.04.1983
# 1  23.04.2020  18.10.1986
# 2  23.04.2020  12.01.1987
# 3  23.04.2020  23.03.1988
# 4  23.04.2020  20.10.1990

# %%
data.shape
# Out:
# (1901, 16)

# %%
#missing values
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1901 entries, 0 to 1900
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        1901 non-null   int64
#  1   name        1901 non-null   object
#  2   agency      1874 non-null   object
#  3   real name   1566 non-null   object
#  4   group       1901 non-null   object
#  5   age         1725 non-null   float64
#  6   height      1603 non-null   float64
#  7   weight      1253 non-null   float64
#  8   blood type  1349 non-null   object
#  9   origin      686 non-null    object
#  10  country     1895 non-null   object
#  11  position    1836 non-null   object
#  12  industry    1901 non-null   object
#  13  gender      1901 non-null   object
#  14  curr date   1901 non-null   object
#  15  birth date  1725 non-null   object
# dtypes: float64(3), int64(1), object(12)
# memory usage: 237.8+ KB

# %%
#determine the amount of missing values
data.isnull().sum()
# Out:
# rank             0
# name             0
# agency          27
# real name      335
# group            0
# age            176
# height         298
# weight         648
# blood type     552
# origin        1215
# country          6
# position        65
# industry         0
# gender           0
# curr date        0
# birth date     176
# dtype: int64

# %%
#drop the columns
data.drop('real name',axis=1,inplace=True)
data.drop('origin',axis=1,inplace=True)
data.drop('industry',axis=1,inplace=True)
data.drop('curr date',axis=1,inplace=True)
data.drop('birth date',axis=1,inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1901 entries, 0 to 1900
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        1901 non-null   int64
#  1   name        1901 non-null   object
#  2   agency      1874 non-null   object
#  3   group       1901 non-null   object
#  4   age         1725 non-null   float64
#  5   height      1603 non-null   float64
#  6   weight      1253 non-null   float64
#  7   blood type  1349 non-null   object
#  8   country     1895 non-null   object
#  9   position    1836 non-null   object
#  10  gender      1901 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 163.5+ KB

# %%
#read new dataset of popular groups
popular = pd.read_csv("bestkpopgroups.csv",sep="\t",delimiter = ";")
popular.head()
# Out:
#    Rank               Group                  Label
# 0     1  BTS (Bangtan Boys)  Big Hit Entertainment
# 1     2          Black Pink        YG Entertaiment
# 2     3                GOT7      JYP Entertainment
# 3     4                 EXO       SM Entertainment
# 4     5         Stray Kinds      JYP Entertainment

# %%
popular.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rank    100 non-null    int64
#  1   Group   100 non-null    object
#  2   Label   100 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 2.5+ KB

# %%
#add new column popularity
data['popularity'] = 0
p = data['popularity']
data.head()
# Out:
#    rank   name            agency      group   age  height  weight blood type  \
# 0     1  Jinah  주식회사 씨그널엔터테인먼트그룹  Berry Chu  37.0     NaN     NaN        NaN
# 1     2  Hayul  주식회사 씨그널엔터테인먼트그룹  Berry Chu  33.0     NaN     NaN        NaN
# 2     3  Jieun  주식회사 씨그널엔터테인먼트그룹  Berry Chu  33.0     NaN     NaN        NaN
# 3     4  Yunmi  주식회사 씨그널엔터테인먼트그룹  Berry Chu  32.0     NaN     NaN        NaN
# 4     5   Haum  주식회사 씨그널엔터테인먼트그룹  Berry Chu  29.0     NaN     NaN        NaN
#
#        country          position  gender  popularity
# 0  South Korea  Leader, Vocalist  Female           0
# 1  South Korea          Vocalist  Female           0
# 2  South Korea          Vocalist  Female           0
# 3  South Korea          Vocalist  Female           0
# 4  South Korea  Vocalist, Maknae  Female           0

# %%
#compare two datasets
#if group contains in dataset with popular group
#then we equal values of column popularity from 0 to 1
for index1, row1 in data.iterrows():
    for index2, row2 in popular.iterrows():
        if(row1['group']==row2['Group']):
            p[index1]=1
# Out:
# /Users/kamila/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
data.head(30)
# Out:
#     rank         name                 agency         group   age  height  \
# 0      1        Jinah       주식회사 씨그널엔터테인먼트그룹     Berry Chu  37.0     NaN
# 1      2        Hayul       주식회사 씨그널엔터테인먼트그룹     Berry Chu  33.0     NaN
# 2      3        Jieun       주식회사 씨그널엔터테인먼트그룹     Berry Chu  33.0     NaN
# 3      4        Yunmi       주식회사 씨그널엔터테인먼트그룹     Berry Chu  32.0     NaN
# 4      5         Haum       주식회사 씨그널엔터테인먼트그룹     Berry Chu  29.0     NaN
# 5      6        Soyou       주식회사 씨그널엔터테인먼트그룹     Berry Chu  34.0     NaN
# 6      7        Vanya  Zenith Media Contents       Z-Girls  23.0   159.0
# 7      8          Roy  Zenith Media Contents        Z-Boys  23.0     NaN
# 8      9         Josh  Zenith Media Contents        Z-Boys  22.0   174.0
# 9     10          Sid  Zenith Media Contents        Z-Boys  20.0     NaN
# 10    11          Gai  Zenith Media Contents        Z-Boys  19.0     NaN
# 11    12        Blink  Zenith Media Contents        Z-Boys  15.0     NaN
# 12    13       Carlyn  Zenith Media Contents       Z-Girls  24.0   160.0
# 13    14       Mahiro  Zenith Media Contents       Z-Girls  24.0   156.0
# 14    15       Bell    Zenith Media Contents       Z-Girls  16.0   156.0
# 15    16        Queen  Zenith Media Contents       Z-Girls  23.0   162.0
# 16    17     Priyanka  Zenith Media Contents       Z-Girls  22.0   155.0
# 17    18       Joanne  Zenith Media Contents       Z-Girls  19.0   173.0
# 18    19        Mavin  Zenith Media Contents        Z-Boys  24.0   168.0
# 19    20        Perry  Zenith Media Contents        Z-Boys  25.0     NaN
# 20    21        Sejin           Zenith Media       Wanna.B  29.0   166.0
# 21    22        Roeun           Zenith Media       Wanna.B  29.0   160.0
# 22    23  Bang Hyunah           Zenith Media       Wanna.B  29.0   161.0
# 23    24          Ami           Zenith Media       Wanna.B  25.0   170.0
# 24    25       Eunsom           Zenith Media       Wanna.B  25.0   165.0
# 25    26   Cheng Xiao   Yuehua Entertainment  Cosmic Girls  21.0   167.0
# 26    27         Luda   Yuehua Entertainment  Cosmic Girls  23.0   157.0
# 27    28         Onda   Yuehua Entertainment      EVERGLOW  19.0   166.0
# 28    29         Yibo   Yuehua Entertainment          UNIQ  22.0   182.0
# 29    30    Seungyoun   Yuehua Entertainment          UNIQ  23.0   180.0
#
#     weight blood type      country  \
# 0      NaN        NaN  South Korea
# 1      NaN        NaN  South Korea
# 2      NaN        NaN  South Korea
# 3      NaN        NaN  South Korea
# 4      NaN        NaN  South Korea
# 5      NaN        NaN  South Korea
# 6     50.0          O    Indonesia
# 7      NaN        NaN      Vietnam
# 8      NaN        NaN  Philippines
# 9      NaN        NaN        India
# 10     NaN        NaN        Japan
# 11     NaN        NaN     Thailand
# 12    45.0        NaN  Philippines
# 13    43.0          A        Japan
# 14    43.0        NaN     Thailand
# 15    49.0        NaN      Vietnam
# 16    43.0        NaN        India
# 17    50.0        NaN       Taiwan
# 18     NaN        NaN    Indonesia
# 19     NaN        NaN       Taiwan
# 20    47.0        NaN  South Korea
# 21    45.0        NaN  South Korea
# 22    44.0        NaN  South Korea
# 23    49.0        NaN  South Korea
# 24    47.0        NaN  South Korea
# 25     NaN          B        China
# 26     NaN          A  South Korea
# 27     NaN          B  South Korea
# 28    59.0          A  South Korea
# 29    65.0          O  South Korea
#
#                                             position  gender  popularity
# 0                                   Leader, Vocalist  Female           0
# 1                                           Vocalist  Female           0
# 2                                           Vocalist  Female           0
# 3                                           Vocalist  Female           0
# 4                                   Vocalist, Maknae  Female           0
# 5                                           Vocalist  Female           0
# 6            Lead Vocalist, Main Dancer, Lead Rapper  Female           0
# 7                                      Main Vocalist    Male           0
# 8                         Main Dancer, Lead Vocalist    Male           0
# 9                                      Main Vocalist    Male           0
# 10        Main Rapper, Lead Dancer, Vocalist, Visual    Male           0
# 11                                  Vocalist, Maknae    Male           0
# 12        Leader, Main Vocalist, Lead Dancer, Center  Female           0
# 13                             Lead Vocalist, Visual  Female           0
# 14           Lead Dancer, Rapper, Vocalist, Youngest  Female           0
# 15            Main Rapper, Lead Dancer, Sub Vocalist  Female           0
# 16                                     Main Vocalist  Female           0
# 17                     Lead Dancer, Vocalist, Visual  Female           0
# 18        Leader, Lead Dancer, Lead Rapper, Vocalist    Male           0
# 19                        Lead Vocalist, Lead Dancer    Male           0
# 20                Leader, Main Vocalist, Lead Rapper  Female           0
# 21                                     Main Vocalist  Female           0
# 22                    Main Rapper, Vocalist, Center,  Female           0
# 23                     Main Dancer, Vocalist, Visual  Female           0
# 24                Lead Vocalist, Lead Dancer, Maknae  Female           0
# 25  Main Dancer, Vocalist, Visual, Face Of the Group  Female           0
# 26                             Lead Rapper, Vocalist  Female           0
# 27                Lead Vocalist, Lead Dancer, Visual  Female           1
# 28     Main Dancer, Rapper, Vocalist, Visual, Maknae    Male           0
# 29                             Main Rapper, Vocalist    Male           0

# %%
def bar_chart(dt):
    popular = data[data['popularity']==1][dt].value_counts()
    unpopular = data[data['popularity']==0][dt].value_counts()
    df = pd.DataFrame([popular,unpopular])
    df.index = ['Popular','Unpopular']
    df.plot(kind='bar',stacked=True,figsize=(10,5))

# %%
#bar chart for gender category
bar_chart('gender')

# %%
# We can see that male groups more popular than female
